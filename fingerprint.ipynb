# %%
# !wget http://bias.csr.unibo.it/fvc2004/download.asp?Db=DB1_B -O fvc2004_DB1_B.zip
# !unzip -q fvc2004_DB1_B.zip -d fvc2004
# Out:
# --2025-05-30 15:39:06--  http://bias.csr.unibo.it/fvc2004/download.asp?Db=DB1_B
# Resolving bias.csr.unibo.it (bias.csr.unibo.it)... 137.204.72.188
# Connecting to bias.csr.unibo.it (bias.csr.unibo.it)|137.204.72.188|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8023 (7.8K) [text/html]
# Saving to: ‘fvc2004_DB1_B.zip’
#
# fvc2004_DB1_B.zip   100%[===================>]   7.83K  --.-KB/s    in 0s
#
# 2025-05-30 15:39:06 (623 MB/s) - ‘fvc2004_DB1_B.zip’ saved [8023/8023]
#
# [fvc2004_DB1_B.zip]
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of fvc2004_DB1_B.zip or
#         fvc2004_DB1_B.zip.zip, and cannot find fvc2004_DB1_B.zip.ZIP, period.

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d ruizgara/socofing
# !unzip socofing.zip -d socofing
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: socofing/socofing/SOCOFing/Real/191__F_Left_index_finger.BMP
#   inflating: socofing/socofing/SOCOFing/Real/191__F_Left_little_finger.BMP
#   inflating: socofing/socofing/SOCOFing/Real/191__F_Left_middle_finger.BMP
#   inflating: socofing/socofing/SOCOFing/Real/191__F_Left_ring_finger.BMP
#   inflating: socofing/socofing/SOCOFing/Real/191__F_Left_thumb_finger.BMP
#   inflating: socofing/socofing/SOCOFing/Real/191__F_Right_index_finger.BMP
#   inflating: socofing/socofing/SOCOFing/Real/191__F_Right_little_finger.BMP
#   inflating: socofing/socofing/SOCOFing/Real/191__F_Right_middle_finger.BMP
#   inflating: socofing/socofing/SOCOFing/Real/191__F_Right_ring_finger.BMP
#   inflating: socofing/socofing/SOCOFing/Real/191__F_Right_thumb_finger.BMP
#   inflating: socofing/socofing/SOCOFing/Real/192__M_Left_index_finger.BMP
#   inflating: socofing/socofing/SOCOFing/Real/192__M_Left_little_finger.BMP
# ...

# %%
# !git clone https://github.com/XiongjunGuan/FpEnhancer.git
# %cd FpEnhancer
# Out:
# Cloning into 'FpEnhancer'...
# remote: Enumerating objects: 187, done.
# remote: Counting objects: 100% (187/187), done.
# remote: Compressing objects: 100% (157/157), done.
# remote: Total 187 (delta 58), reused 144 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (187/187), 15.71 MiB | 29.46 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# /content/FpEnhancer/FpEnhancer

# %%
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# SOCOFing
data_path = "/content/socofing/SOCOFing/Real"
images = []
labels = []

for file in os.listdir(data_path):
    if file.endswith(".BMP"):
        path = os.path.join(data_path, file)
        img = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
        img = cv2.resize(img, (64, 64))  #
        images.append(img.flatten())    #
        label = file.split("__")[0]     #
        labels.append(label)

#
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

#
model = SVC(kernel='linear')
model.fit(X_train, y_train)

#
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.023333333333333334

# %%
# !cp "/content/drive/MyDrive/FVC2004/101_1.tif"
# Out:
# cp: missing destination file operand after '/content/drive/MyDrive/FVC2004/101_1.tif'
# Try 'cp --help' for more information.
